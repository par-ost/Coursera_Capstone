# %% [markdown]
# # Summary
# This is a model used to predict the weather in Dunedin, New Zealand. Daily weather dataset from 2016-2019 were used. There are two models made:
# + Full year air temperature prediction
# + Half year air temperature prediction

# %% [markdown]
# # Importing moduels and loading datasets

# %%
import pandas as pd 
import pygal
from pygal.style import DarkStyle
from IPython.display import SVG, HTML, display
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score,mean_absolute_error
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler


six = pd.read_csv('./Weather_Data/daily/2016.csv').rename(columns={'Date(NZST)': 'Date','Tair(C)':'AirTemp'})
print(f'Loaded 2016, Shape:{six.shape}')
sev = pd.read_csv('./Weather_Data/daily/2017.csv').rename(columns={'Date(NZST)': 'Date','Tair(C)':'AirTemp'})
print(f'Loaded 2017, Shape:{sev.shape}')

Xlist = ['AirTemp','RH(%)'] #
Yvar = 'AirTemp'
# RH - relative humidity
# Tair - Temperature of air    <== What we want to predict 
display(six.head(3))
display(sev.head(3))
# Out:
# Loaded 2016, Shape:(717, 6)
# Loaded 2017, Shape:(728, 6)
#    Station           Date  AirTemp  Twet(C)  RH(%)  Tdew(C)
# 0    15752  20160101:0800     16.4     13.0   66.0     10.0
# 1     3925  20160101:0800     17.1     15.3   82.0     14.0
# 2    15752  20160102:0800     16.2     13.7   74.0     11.6
#    Station           Date  AirTemp  Twet(C)  RH(%)  Tdew(C)
# 0    15752  20170101:0800     15.6     14.3   86.0     13.3
# 1     3925  20170101:0800     18.2     17.2   90.0     16.5
# 2    15752  20170102:0800     10.4      8.2   72.0      5.6

# %% [markdown]
# # Data & Feature engineering
# + cleaning<br>
#   - Seprated the data into the two corresponding stations in Dunedin
#   - Made sure the data used have the same length as some dates are missing.
# + visualisation
#   - Humidity and Air Temperature have a inverse relationship

# %%
#Seperating data by stations
Stations = {
    'One': 15752,
    'Two': 3925
}
sixOne = six[six['Station'] == Stations['One']].reset_index()
sixTwo = six[six['Station'] == Stations['Two']].reset_index()

sevOne = sev[sev['Station'] == Stations['One']].reset_index()
sevTwo = sev[sev['Station'] == Stations['Two']].reset_index()

display(sixOne.shape)
display(sevOne.shape)
# Out:
# (352, 7)
# (364, 7)

# %%
#Ensure data have same dates and missing days does not affect the model
def clean(X, Y):
    Xdates = [i[4:(len(i)-1)] for i in list(X['Date'])]
    Ydates = [i[4:(len(i)-1)] for i in list(Y['Date'])]
    yfilt = []
    xfilt = []
    for i in Xdates:
        if i in Ydates:
            yfilt.append(Ydates.index(i))
            xfilt.append(Xdates.index(i))

    Yres = Y.iloc[yfilt].reset_index()
    Xres = X.iloc[xfilt].reset_index()

    if Yres.shape == Xres.shape:
        return (Yres,Xres)
    else:
        print('Filter Error.')

(Yone, Xone) = clean(sixOne,sevOne)
(Ytwo, Xtwo) = clean(sixTwo,sixOne)
Xone.head()
# Out:
#    level_0  index  Station           Date  AirTemp  Twet(C)  RH(%)  Tdew(C)
# 0        0      0    15752  20160101:0800     16.4     13.0   66.0     10.0
# 1        1      2    15752  20160102:0800     16.2     13.7   74.0     11.6
# 2        2      4    15752  20160103:0800     10.8      9.8   87.0      8.7
# 3        3      6    15752  20160104:0800      9.6      7.0   66.0      3.6
# 4        4      8    15752  20160105:0800     12.2      9.5   68.0      6.5

# %%
html_pygal = """
<!DOCTYPE html>
<html>
  <head>
  <script type="text/javascript" src="http://kozea.github.com/pygal.js/javascripts/svg.jquery.js"></script>
  <script type="text/javascript" src="http://kozea.github.com/pygal.js/javascripts/pygal-tooltips.js"></script>
    <!-- ... -->
  </head>
  <body>
    <figure>
      {pygal_render}
    </figure>   
  </body>
</html>
"""

#Visualising Station One
chart1 = pygal.Line(style=DarkStyle, dots_size=0,legend_at_bottom=True)
chart1.add('2016 Air Temp', Xone['AirTemp'])
chart1.add('Relative humidity', Xone['RH(%)'], secondary=True)
chart1.title = 'Station one'
chart1.add('2017 Air Temp', Yone['AirTemp']) #dependent variable

#Visualising Station 2
chart2 = pygal.Line(style=DarkStyle, dots_size=0,legend_at_bottom=True)
chart2.add('2016 Air Temp', Xtwo['AirTemp'])
chart2.add('Relative humidity', Xtwo['RH(%)'], secondary=True)
chart2.title = 'Station two'
chart2.add('2017 Air Temp', Ytwo['AirTemp']) #dependent variable

display(HTML(html_pygal.format(pygal_render=chart1.render())))
display(HTML(html_pygal.format(pygal_render=chart2.render())))
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#   <script type="text/javascript" src="http://kozea.github.com/pygal.js/javascripts/svg.jquery.js"></script>
#   <script type="text/javascript" src="http://kozea.github.com/pygal.js/javascripts/pygal-tooltips.js"></script>
#     <!-- ... -->
#   </head>
#   <body>
#     <figure>
#       b'<?xml version=\'1.0\' encoding=\'utf-8\'?>\n<svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="chart-28703eb4-5a27-476e-b8fd-79cbd3d9af7f" class="pygal-chart" viewBox="0 0 800 600"><!--Generated with pygal 2.4.0 (lxml) \xc2\xa9Kozea 2012-2016 on 2020-06-19--><!--http://pygal.org--><!--http://github.com/Kozea/pygal--><defs><style type="text/css">#chart-28703eb4-5a27-476e-b8fd-79cbd3d9af7f{-webkit-user-select:none;-webkit-font-smoothing:antialiased;font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace}#chart-28703eb4-5a27-476e-b8fd-79cbd3d9af7f .title{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-28703eb4-5a27-476e-b8fd-79cbd3d9af7f .legends .legend text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-28703eb4-5a27-476e-b8fd-79cbd3d9af7f .axis text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-28703eb4-5a27-476e-b8fd-79cbd3d9af7f .axis text.major{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-28703eb4-5a27-476e-b8fd-79cbd3d9af7f .text-overlay text.value{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-28703eb4-5a27-476e-b8fd-79cbd3d9af7f .text-overlay text.label{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-28703eb4-5a27-476e-b8fd-79cbd3d9af7f .tooltip{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-28703eb4-5a27-476e-b8fd-79cbd3d9af7f text.no_data{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:64px}\n#chart-28703eb4-5a27-476e-b8fd-79cbd3d9af7f{background-color:black}#chart-28703eb4-5a27-476e-b8fd-79cbd3d9af7f path,#chart-28703eb4-5a27-476e-b8fd-79cbd3d9af7f line,#chart-28703eb4-5a27-476e-b8fd-79cbd3d9af7f rect,#chart-28703eb4-5a27-476e-b8fd-79cbd3d9af7f circle{-webkit-transition:250ms;-moz-transition:250ms;transition:250ms}#chart-28703eb4-5a27-476e-b8fd-79cbd3d9af7f .graph &gt; .background{fill:black}#chart-28703eb4-5a27-476e-b8fd-79cbd3d9af7f .plot &gt; .background{fill:#111}#chart-28703eb4-5a27-476e-b8fd-79cbd3d9af7f .graph{fill:#999}#chart-28703eb4-5a27-476e-b8fd-79cbd3d9af7f text.no_data{fill:#eee}#chart-28703eb4-5a27-476e-b8fd-79cbd3d9af7f .title{fill:#eee}#chart-28703eb4-5a27-476e-b8fd-79cbd3d9af7f .legends .legend text{fill:#999}#chart-28703eb4-5a27-476e-b8fd-79cbd3d9af7f .legends .legend:hover text{fill:#eee}#chart-28703eb4-5a27-476e-b8fd-79cbd3d9af7f .axis .line{stroke:#eee}#chart-28703eb4-5a27-476e-b8fd-79cbd3d9af7f .axis .guide.line{stroke:#555}#chart-28703eb4-5a27-476e-b8fd-79cbd3d9af7f .axis .major.line{stroke:#999}#chart-28703eb4-5a27-476e-b8fd-79cbd3d9af7f .axis text.major{fill:#eee}#chart-28703eb4-5a27-476e-b8fd-79cbd3d9af7f .axis.y .guides:hover .guide.line,#chart-28703eb4-5a27-476e-b8fd-79cbd3d9af7f .line-graph .axis.x .guides:hover .guide.line,#chart-28703eb4-5a27-476e-b8fd-79cbd3d9af7f .stackedline-graph .axis.x .guides:hover .guide.line,#chart-28703eb4-5a27-476e-b8fd-79cbd3d9af7f .xy-graph .axis.x .guides:hover .guide.line{stroke:#eee}#chart-28703eb4-5a27-476e-b8fd-79cbd3d9af7f .axis .guides:hover text{fill:#eee}#chart-28703eb4-5a27-476e-b8fd-79cbd3d9af7f .reactive{fill-opacity:.8;stroke-opacity:.8}#chart-28703eb4-5a27-476e-b8fd-79cbd3d9af7f .ci{stroke:#999}#chart-28703eb4-5a27-476e-b8fd-79cbd3d9af7f .reactive.active,#chart-28703eb4-5a27-476e-b8fd-79cbd3d9af7f .active .reactive{fill-opacity:.4;stroke-opacity:.9;stroke-width:4}#chart-28703eb4-5a27-476e-b8fd-79cbd3d9af7f .ci .reactive.active{stroke-width:1.5}#chart-28703eb4-5a27-476e-b8fd-79cbd3d9af7f .series text{fill:#eee}#chart-28703eb4-5a27-476e-b8fd-79cbd3d9af7f .tooltip rect{fill:#111;stroke:#eee;-webkit-transition:opacity 250ms;-moz-transition:opacity 250ms;transition:opacity 250ms}#chart-28703eb4-5a27-476e-b8fd-79cbd3d9af7f .tooltip .label{fill:#999}#chart-28703eb4-5a27-476e-b8fd-79cbd3d9af7f .tooltip .label{fill: ...
# <!DOCTYPE html>
# <html>
#   <head>
#   <script type="text/javascript" src="http://kozea.github.com/pygal.js/javascripts/svg.jquery.js"></script>
#   <script type="text/javascript" src="http://kozea.github.com/pygal.js/javascripts/pygal-tooltips.js"></script>
#     <!-- ... -->
#   </head>
#   <body>
#     <figure>
#       b'<?xml version=\'1.0\' encoding=\'utf-8\'?>\n<svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="chart-569c9c9c-3277-41e4-bf88-c963dbc2d738" class="pygal-chart" viewBox="0 0 800 600"><!--Generated with pygal 2.4.0 (lxml) \xc2\xa9Kozea 2012-2016 on 2020-06-19--><!--http://pygal.org--><!--http://github.com/Kozea/pygal--><defs><style type="text/css">#chart-569c9c9c-3277-41e4-bf88-c963dbc2d738{-webkit-user-select:none;-webkit-font-smoothing:antialiased;font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace}#chart-569c9c9c-3277-41e4-bf88-c963dbc2d738 .title{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-569c9c9c-3277-41e4-bf88-c963dbc2d738 .legends .legend text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-569c9c9c-3277-41e4-bf88-c963dbc2d738 .axis text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-569c9c9c-3277-41e4-bf88-c963dbc2d738 .axis text.major{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-569c9c9c-3277-41e4-bf88-c963dbc2d738 .text-overlay text.value{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-569c9c9c-3277-41e4-bf88-c963dbc2d738 .text-overlay text.label{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-569c9c9c-3277-41e4-bf88-c963dbc2d738 .tooltip{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-569c9c9c-3277-41e4-bf88-c963dbc2d738 text.no_data{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:64px}\n#chart-569c9c9c-3277-41e4-bf88-c963dbc2d738{background-color:black}#chart-569c9c9c-3277-41e4-bf88-c963dbc2d738 path,#chart-569c9c9c-3277-41e4-bf88-c963dbc2d738 line,#chart-569c9c9c-3277-41e4-bf88-c963dbc2d738 rect,#chart-569c9c9c-3277-41e4-bf88-c963dbc2d738 circle{-webkit-transition:250ms;-moz-transition:250ms;transition:250ms}#chart-569c9c9c-3277-41e4-bf88-c963dbc2d738 .graph &gt; .background{fill:black}#chart-569c9c9c-3277-41e4-bf88-c963dbc2d738 .plot &gt; .background{fill:#111}#chart-569c9c9c-3277-41e4-bf88-c963dbc2d738 .graph{fill:#999}#chart-569c9c9c-3277-41e4-bf88-c963dbc2d738 text.no_data{fill:#eee}#chart-569c9c9c-3277-41e4-bf88-c963dbc2d738 .title{fill:#eee}#chart-569c9c9c-3277-41e4-bf88-c963dbc2d738 .legends .legend text{fill:#999}#chart-569c9c9c-3277-41e4-bf88-c963dbc2d738 .legends .legend:hover text{fill:#eee}#chart-569c9c9c-3277-41e4-bf88-c963dbc2d738 .axis .line{stroke:#eee}#chart-569c9c9c-3277-41e4-bf88-c963dbc2d738 .axis .guide.line{stroke:#555}#chart-569c9c9c-3277-41e4-bf88-c963dbc2d738 .axis .major.line{stroke:#999}#chart-569c9c9c-3277-41e4-bf88-c963dbc2d738 .axis text.major{fill:#eee}#chart-569c9c9c-3277-41e4-bf88-c963dbc2d738 .axis.y .guides:hover .guide.line,#chart-569c9c9c-3277-41e4-bf88-c963dbc2d738 .line-graph .axis.x .guides:hover .guide.line,#chart-569c9c9c-3277-41e4-bf88-c963dbc2d738 .stackedline-graph .axis.x .guides:hover .guide.line,#chart-569c9c9c-3277-41e4-bf88-c963dbc2d738 .xy-graph .axis.x .guides:hover .guide.line{stroke:#eee}#chart-569c9c9c-3277-41e4-bf88-c963dbc2d738 .axis .guides:hover text{fill:#eee}#chart-569c9c9c-3277-41e4-bf88-c963dbc2d738 .reactive{fill-opacity:.8;stroke-opacity:.8}#chart-569c9c9c-3277-41e4-bf88-c963dbc2d738 .ci{stroke:#999}#chart-569c9c9c-3277-41e4-bf88-c963dbc2d738 .reactive.active,#chart-569c9c9c-3277-41e4-bf88-c963dbc2d738 .active .reactive{fill-opacity:.4;stroke-opacity:.9;stroke-width:4}#chart-569c9c9c-3277-41e4-bf88-c963dbc2d738 .ci .reactive.active{stroke-width:1.5}#chart-569c9c9c-3277-41e4-bf88-c963dbc2d738 .series text{fill:#eee}#chart-569c9c9c-3277-41e4-bf88-c963dbc2d738 .tooltip rect{fill:#111;stroke:#eee;-webkit-transition:opacity 250ms;-moz-transition:opacity 250ms;transition:opacity 250ms}#chart-569c9c9c-3277-41e4-bf88-c963dbc2d738 .tooltip .label{fill:#999}#chart-569c9c9c-3277-41e4-bf88-c963dbc2d738 .tooltip .label{fill: ...

# %%
scatter = pygal.XY(stroke=False, style=DarkStyle)
count = min([len(list(Xone['AirTemp'])), len(list(Yone['AirTemp']))])
xy = []
i=0
while i < count:
    xy.append((Xone['AirTemp'][i],Yone['AirTemp'][i]))
    i+=1
scatter.add('A', xy)
display(HTML(html_pygal.format(pygal_render=scatter.render())))
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#   <script type="text/javascript" src="http://kozea.github.com/pygal.js/javascripts/svg.jquery.js"></script>
#   <script type="text/javascript" src="http://kozea.github.com/pygal.js/javascripts/pygal-tooltips.js"></script>
#     <!-- ... -->
#   </head>
#   <body>
#     <figure>
#       b'<?xml version=\'1.0\' encoding=\'utf-8\'?>\n<svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="chart-ad1388ec-794c-4118-8f1b-69cfdf329566" class="pygal-chart" viewBox="0 0 800 600"><!--Generated with pygal 2.4.0 (lxml) \xc2\xa9Kozea 2012-2016 on 2020-06-19--><!--http://pygal.org--><!--http://github.com/Kozea/pygal--><defs><style type="text/css">#chart-ad1388ec-794c-4118-8f1b-69cfdf329566{-webkit-user-select:none;-webkit-font-smoothing:antialiased;font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace}#chart-ad1388ec-794c-4118-8f1b-69cfdf329566 .title{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-ad1388ec-794c-4118-8f1b-69cfdf329566 .legends .legend text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-ad1388ec-794c-4118-8f1b-69cfdf329566 .axis text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-ad1388ec-794c-4118-8f1b-69cfdf329566 .axis text.major{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-ad1388ec-794c-4118-8f1b-69cfdf329566 .text-overlay text.value{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-ad1388ec-794c-4118-8f1b-69cfdf329566 .text-overlay text.label{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-ad1388ec-794c-4118-8f1b-69cfdf329566 .tooltip{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-ad1388ec-794c-4118-8f1b-69cfdf329566 text.no_data{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:64px}\n#chart-ad1388ec-794c-4118-8f1b-69cfdf329566{background-color:black}#chart-ad1388ec-794c-4118-8f1b-69cfdf329566 path,#chart-ad1388ec-794c-4118-8f1b-69cfdf329566 line,#chart-ad1388ec-794c-4118-8f1b-69cfdf329566 rect,#chart-ad1388ec-794c-4118-8f1b-69cfdf329566 circle{-webkit-transition:250ms;-moz-transition:250ms;transition:250ms}#chart-ad1388ec-794c-4118-8f1b-69cfdf329566 .graph &gt; .background{fill:black}#chart-ad1388ec-794c-4118-8f1b-69cfdf329566 .plot &gt; .background{fill:#111}#chart-ad1388ec-794c-4118-8f1b-69cfdf329566 .graph{fill:#999}#chart-ad1388ec-794c-4118-8f1b-69cfdf329566 text.no_data{fill:#eee}#chart-ad1388ec-794c-4118-8f1b-69cfdf329566 .title{fill:#eee}#chart-ad1388ec-794c-4118-8f1b-69cfdf329566 .legends .legend text{fill:#999}#chart-ad1388ec-794c-4118-8f1b-69cfdf329566 .legends .legend:hover text{fill:#eee}#chart-ad1388ec-794c-4118-8f1b-69cfdf329566 .axis .line{stroke:#eee}#chart-ad1388ec-794c-4118-8f1b-69cfdf329566 .axis .guide.line{stroke:#555}#chart-ad1388ec-794c-4118-8f1b-69cfdf329566 .axis .major.line{stroke:#999}#chart-ad1388ec-794c-4118-8f1b-69cfdf329566 .axis text.major{fill:#eee}#chart-ad1388ec-794c-4118-8f1b-69cfdf329566 .axis.y .guides:hover .guide.line,#chart-ad1388ec-794c-4118-8f1b-69cfdf329566 .line-graph .axis.x .guides:hover .guide.line,#chart-ad1388ec-794c-4118-8f1b-69cfdf329566 .stackedline-graph .axis.x .guides:hover .guide.line,#chart-ad1388ec-794c-4118-8f1b-69cfdf329566 .xy-graph .axis.x .guides:hover .guide.line{stroke:#eee}#chart-ad1388ec-794c-4118-8f1b-69cfdf329566 .axis .guides:hover text{fill:#eee}#chart-ad1388ec-794c-4118-8f1b-69cfdf329566 .reactive{fill-opacity:.8;stroke-opacity:.8}#chart-ad1388ec-794c-4118-8f1b-69cfdf329566 .ci{stroke:#999}#chart-ad1388ec-794c-4118-8f1b-69cfdf329566 .reactive.active,#chart-ad1388ec-794c-4118-8f1b-69cfdf329566 .active .reactive{fill-opacity:.4;stroke-opacity:.9;stroke-width:4}#chart-ad1388ec-794c-4118-8f1b-69cfdf329566 .ci .reactive.active{stroke-width:1.5}#chart-ad1388ec-794c-4118-8f1b-69cfdf329566 .series text{fill:#eee}#chart-ad1388ec-794c-4118-8f1b-69cfdf329566 .tooltip rect{fill:#111;stroke:#eee;-webkit-transition:opacity 250ms;-moz-transition:opacity 250ms;transition:opacity 250ms}#chart-ad1388ec-794c-4118-8f1b-69cfdf329566 .tooltip .label{fill:#999}#chart-ad1388ec-794c-4118-8f1b-69cfdf329566 .tooltip .label{fill: ...

# %%
def optimizeModel(X,Y):
    X = X[Xlist]
    Y = Y[Yvar]

    X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.4, random_state=0)
    sScal = StandardScaler()
    X_train = sScal.fit_transform(X_train)
    X_test = sScal.transform(X_test)

    for i in [1,2,3,4,5,6,7,8]:
        regressor = RandomForestRegressor(max_depth=i, random_state=1)
        regressor.fit(X_train, y_train)
        y_pred = regressor.predict(X_test)
        r2 = r2_score(y_pred, y_test)
        mae = mean_absolute_error(y_pred,y_test)
        print(f'When i="{i}\n   R2={r2}\n    Mean Absolute Error = {mae}')

optimizeModel(Xone, Yone)
print('-----------------')
optimizeModel(Xtwo, Ytwo)
# Out:
# When i="1
#    R2=-0.7168651655963749
#     Mean Absolute Error = 2.836099801027406
# When i="2
#    R2=-0.46683429988878844
#     Mean Absolute Error = 2.8647996919564807
# When i="3
#    R2=-0.42199226418147395
#     Mean Absolute Error = 2.8929101181179853
# When i="4
#    R2=-0.3346072146420558
#     Mean Absolute Error = 2.9345474052888654
# When i="5
#    R2=-0.3009787020038732
#     Mean Absolute Error = 3.0152524289802614
# When i="6
#    R2=-0.25530438682013434
#     Mean Absolute Error = 3.0734568637411606
# When i="7
#    R2=-0.21497522707168248
#     Mean Absolute Error = 3.1290361362794923
# When i="8
#    R2=-0.1994395064586838
#     Mean Absolute Error = 3.178714732357899
# -----------------
# When i="1
#    R2=-0.8213156263711219
#     Mean Absolute Error = 2.760852713533471
# When i="2
#    R2=-0.3114469745419486
#     Mean Absolute Error = 2.576400551860028
# When i="3
#    R2=-0.1515960208703726
#     Mean Absolute Error = 2.5599221170598696
# When i="4
#    R2=-0.019674456221785652
#     Mean Absolute Error = 2.555674170336237
# When i="5
#    R2=0.025754313538597917
#     Mean Absolute Error = 2.557856632018825
# When i="6
#    R2=0.0664018921831151
#     Mean Absolute Error = 2.553065472638731
# When i="7
#    R2=0.08081921407064896
#     Mean Absolute Error = 2.5808862481756605
# When i="8
#    R2=0.09351350776267131
#     Mean Absolute Error = 2.5995214224740986

# %%
regressor = RandomForestRegressor(max_depth=7, random_state=2)
reg = LinearRegression()

StationOneModel = regressor.fit(Xone[Xlist], Yone['AirTemp'])
StationTwoModel = regressor.fit(Xtwo[Xlist], Ytwo['AirTemp'])

# Use 2017 data to predict 2018 Air temperature
eig = pd.read_csv('./Weather_Data/daily/2018.csv').rename(columns={'Date(NZST)': 'Date','Tair(C)':'AirTemp'})
sev = pd.read_csv('./Weather_Data/daily/2017.csv').rename(columns={'Date(NZST)': 'Date','Tair(C)':'AirTemp'})

sevOne = sev[sev['Station'] == Stations['One']].reset_index()
sevTwo = sev[sev['Station'] == Stations['Two']].reset_index()
eigOne = eig[eig['Station'] == Stations['One']].reset_index()
eigTwo = eig[eig['Station'] == Stations['Two']].reset_index()

(evYone, evXone) = clean(sevOne,eigOne)
(evYtwo, evXtwo) = clean(sevTwo,eigTwo)

prStationOne = StationOneModel.predict(evXone[Xlist])
r2One = r2_score(prStationOne, evYone['AirTemp'])

prStationTwo = StationTwoModel.predict(evXtwo[Xlist])
r2Two = r2_score(prStationTwo, evYtwo['AirTemp'])

# %%
compChart = pygal.Line(style=DarkStyle, dots_size=0,legend_at_bottom=True)
compChart.title = 'One'
compChart.add('Prediction', list(prStationOne))
compChart.add('Actual', evYone['AirTemp'], secondary=True)

compChart2 = pygal.Line(style=DarkStyle, dots_size=0,legend_at_bottom=True)
compChart2.title = 'One'
compChart2.add('Prediction', list(prStationTwo))
compChart2.add('Actual', evYtwo['AirTemp'], secondary=True)

display(HTML(html_pygal.format(pygal_render=compChart.render())))
display(HTML(html_pygal.format(pygal_render=compChart2.render())))
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#   <script type="text/javascript" src="http://kozea.github.com/pygal.js/javascripts/svg.jquery.js"></script>
#   <script type="text/javascript" src="http://kozea.github.com/pygal.js/javascripts/pygal-tooltips.js"></script>
#     <!-- ... -->
#   </head>
#   <body>
#     <figure>
#       b'<?xml version=\'1.0\' encoding=\'utf-8\'?>\n<svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="chart-6a1e94f6-15fd-4be8-9ef3-7ffbc4a61451" class="pygal-chart" viewBox="0 0 800 600"><!--Generated with pygal 2.4.0 (lxml) \xc2\xa9Kozea 2012-2016 on 2020-06-19--><!--http://pygal.org--><!--http://github.com/Kozea/pygal--><defs><style type="text/css">#chart-6a1e94f6-15fd-4be8-9ef3-7ffbc4a61451{-webkit-user-select:none;-webkit-font-smoothing:antialiased;font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace}#chart-6a1e94f6-15fd-4be8-9ef3-7ffbc4a61451 .title{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-6a1e94f6-15fd-4be8-9ef3-7ffbc4a61451 .legends .legend text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-6a1e94f6-15fd-4be8-9ef3-7ffbc4a61451 .axis text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-6a1e94f6-15fd-4be8-9ef3-7ffbc4a61451 .axis text.major{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-6a1e94f6-15fd-4be8-9ef3-7ffbc4a61451 .text-overlay text.value{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-6a1e94f6-15fd-4be8-9ef3-7ffbc4a61451 .text-overlay text.label{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-6a1e94f6-15fd-4be8-9ef3-7ffbc4a61451 .tooltip{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-6a1e94f6-15fd-4be8-9ef3-7ffbc4a61451 text.no_data{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:64px}\n#chart-6a1e94f6-15fd-4be8-9ef3-7ffbc4a61451{background-color:black}#chart-6a1e94f6-15fd-4be8-9ef3-7ffbc4a61451 path,#chart-6a1e94f6-15fd-4be8-9ef3-7ffbc4a61451 line,#chart-6a1e94f6-15fd-4be8-9ef3-7ffbc4a61451 rect,#chart-6a1e94f6-15fd-4be8-9ef3-7ffbc4a61451 circle{-webkit-transition:250ms;-moz-transition:250ms;transition:250ms}#chart-6a1e94f6-15fd-4be8-9ef3-7ffbc4a61451 .graph &gt; .background{fill:black}#chart-6a1e94f6-15fd-4be8-9ef3-7ffbc4a61451 .plot &gt; .background{fill:#111}#chart-6a1e94f6-15fd-4be8-9ef3-7ffbc4a61451 .graph{fill:#999}#chart-6a1e94f6-15fd-4be8-9ef3-7ffbc4a61451 text.no_data{fill:#eee}#chart-6a1e94f6-15fd-4be8-9ef3-7ffbc4a61451 .title{fill:#eee}#chart-6a1e94f6-15fd-4be8-9ef3-7ffbc4a61451 .legends .legend text{fill:#999}#chart-6a1e94f6-15fd-4be8-9ef3-7ffbc4a61451 .legends .legend:hover text{fill:#eee}#chart-6a1e94f6-15fd-4be8-9ef3-7ffbc4a61451 .axis .line{stroke:#eee}#chart-6a1e94f6-15fd-4be8-9ef3-7ffbc4a61451 .axis .guide.line{stroke:#555}#chart-6a1e94f6-15fd-4be8-9ef3-7ffbc4a61451 .axis .major.line{stroke:#999}#chart-6a1e94f6-15fd-4be8-9ef3-7ffbc4a61451 .axis text.major{fill:#eee}#chart-6a1e94f6-15fd-4be8-9ef3-7ffbc4a61451 .axis.y .guides:hover .guide.line,#chart-6a1e94f6-15fd-4be8-9ef3-7ffbc4a61451 .line-graph .axis.x .guides:hover .guide.line,#chart-6a1e94f6-15fd-4be8-9ef3-7ffbc4a61451 .stackedline-graph .axis.x .guides:hover .guide.line,#chart-6a1e94f6-15fd-4be8-9ef3-7ffbc4a61451 .xy-graph .axis.x .guides:hover .guide.line{stroke:#eee}#chart-6a1e94f6-15fd-4be8-9ef3-7ffbc4a61451 .axis .guides:hover text{fill:#eee}#chart-6a1e94f6-15fd-4be8-9ef3-7ffbc4a61451 .reactive{fill-opacity:.8;stroke-opacity:.8}#chart-6a1e94f6-15fd-4be8-9ef3-7ffbc4a61451 .ci{stroke:#999}#chart-6a1e94f6-15fd-4be8-9ef3-7ffbc4a61451 .reactive.active,#chart-6a1e94f6-15fd-4be8-9ef3-7ffbc4a61451 .active .reactive{fill-opacity:.4;stroke-opacity:.9;stroke-width:4}#chart-6a1e94f6-15fd-4be8-9ef3-7ffbc4a61451 .ci .reactive.active{stroke-width:1.5}#chart-6a1e94f6-15fd-4be8-9ef3-7ffbc4a61451 .series text{fill:#eee}#chart-6a1e94f6-15fd-4be8-9ef3-7ffbc4a61451 .tooltip rect{fill:#111;stroke:#eee;-webkit-transition:opacity 250ms;-moz-transition:opacity 250ms;transition:opacity 250ms}#chart-6a1e94f6-15fd-4be8-9ef3-7ffbc4a61451 .tooltip .label{fill:#999}#chart-6a1e94f6-15fd-4be8-9ef3-7ffbc4a61451 .tooltip .label{fill: ...
# <!DOCTYPE html>
# <html>
#   <head>
#   <script type="text/javascript" src="http://kozea.github.com/pygal.js/javascripts/svg.jquery.js"></script>
#   <script type="text/javascript" src="http://kozea.github.com/pygal.js/javascripts/pygal-tooltips.js"></script>
#     <!-- ... -->
#   </head>
#   <body>
#     <figure>
#       b'<?xml version=\'1.0\' encoding=\'utf-8\'?>\n<svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="chart-fd362347-ad4e-4dfa-9c2c-bb284fe63cb4" class="pygal-chart" viewBox="0 0 800 600"><!--Generated with pygal 2.4.0 (lxml) \xc2\xa9Kozea 2012-2016 on 2020-06-19--><!--http://pygal.org--><!--http://github.com/Kozea/pygal--><defs><style type="text/css">#chart-fd362347-ad4e-4dfa-9c2c-bb284fe63cb4{-webkit-user-select:none;-webkit-font-smoothing:antialiased;font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace}#chart-fd362347-ad4e-4dfa-9c2c-bb284fe63cb4 .title{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-fd362347-ad4e-4dfa-9c2c-bb284fe63cb4 .legends .legend text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-fd362347-ad4e-4dfa-9c2c-bb284fe63cb4 .axis text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-fd362347-ad4e-4dfa-9c2c-bb284fe63cb4 .axis text.major{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-fd362347-ad4e-4dfa-9c2c-bb284fe63cb4 .text-overlay text.value{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-fd362347-ad4e-4dfa-9c2c-bb284fe63cb4 .text-overlay text.label{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-fd362347-ad4e-4dfa-9c2c-bb284fe63cb4 .tooltip{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-fd362347-ad4e-4dfa-9c2c-bb284fe63cb4 text.no_data{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:64px}\n#chart-fd362347-ad4e-4dfa-9c2c-bb284fe63cb4{background-color:black}#chart-fd362347-ad4e-4dfa-9c2c-bb284fe63cb4 path,#chart-fd362347-ad4e-4dfa-9c2c-bb284fe63cb4 line,#chart-fd362347-ad4e-4dfa-9c2c-bb284fe63cb4 rect,#chart-fd362347-ad4e-4dfa-9c2c-bb284fe63cb4 circle{-webkit-transition:250ms;-moz-transition:250ms;transition:250ms}#chart-fd362347-ad4e-4dfa-9c2c-bb284fe63cb4 .graph &gt; .background{fill:black}#chart-fd362347-ad4e-4dfa-9c2c-bb284fe63cb4 .plot &gt; .background{fill:#111}#chart-fd362347-ad4e-4dfa-9c2c-bb284fe63cb4 .graph{fill:#999}#chart-fd362347-ad4e-4dfa-9c2c-bb284fe63cb4 text.no_data{fill:#eee}#chart-fd362347-ad4e-4dfa-9c2c-bb284fe63cb4 .title{fill:#eee}#chart-fd362347-ad4e-4dfa-9c2c-bb284fe63cb4 .legends .legend text{fill:#999}#chart-fd362347-ad4e-4dfa-9c2c-bb284fe63cb4 .legends .legend:hover text{fill:#eee}#chart-fd362347-ad4e-4dfa-9c2c-bb284fe63cb4 .axis .line{stroke:#eee}#chart-fd362347-ad4e-4dfa-9c2c-bb284fe63cb4 .axis .guide.line{stroke:#555}#chart-fd362347-ad4e-4dfa-9c2c-bb284fe63cb4 .axis .major.line{stroke:#999}#chart-fd362347-ad4e-4dfa-9c2c-bb284fe63cb4 .axis text.major{fill:#eee}#chart-fd362347-ad4e-4dfa-9c2c-bb284fe63cb4 .axis.y .guides:hover .guide.line,#chart-fd362347-ad4e-4dfa-9c2c-bb284fe63cb4 .line-graph .axis.x .guides:hover .guide.line,#chart-fd362347-ad4e-4dfa-9c2c-bb284fe63cb4 .stackedline-graph .axis.x .guides:hover .guide.line,#chart-fd362347-ad4e-4dfa-9c2c-bb284fe63cb4 .xy-graph .axis.x .guides:hover .guide.line{stroke:#eee}#chart-fd362347-ad4e-4dfa-9c2c-bb284fe63cb4 .axis .guides:hover text{fill:#eee}#chart-fd362347-ad4e-4dfa-9c2c-bb284fe63cb4 .reactive{fill-opacity:.8;stroke-opacity:.8}#chart-fd362347-ad4e-4dfa-9c2c-bb284fe63cb4 .ci{stroke:#999}#chart-fd362347-ad4e-4dfa-9c2c-bb284fe63cb4 .reactive.active,#chart-fd362347-ad4e-4dfa-9c2c-bb284fe63cb4 .active .reactive{fill-opacity:.4;stroke-opacity:.9;stroke-width:4}#chart-fd362347-ad4e-4dfa-9c2c-bb284fe63cb4 .ci .reactive.active{stroke-width:1.5}#chart-fd362347-ad4e-4dfa-9c2c-bb284fe63cb4 .series text{fill:#eee}#chart-fd362347-ad4e-4dfa-9c2c-bb284fe63cb4 .tooltip rect{fill:#111;stroke:#eee;-webkit-transition:opacity 250ms;-moz-transition:opacity 250ms;transition:opacity 250ms}#chart-fd362347-ad4e-4dfa-9c2c-bb284fe63cb4 .tooltip .label{fill:#999}#chart-fd362347-ad4e-4dfa-9c2c-bb284fe63cb4 .tooltip .label{fill: ...

# %%
eig = pd.read_csv('./Weather_Data/daily/2018.csv').rename(columns={'Date(NZST)': 'Date','Tair(C)':'AirTemp'})
sev = pd.read_csv('./Weather_Data/daily/2017.csv').rename(columns={'Date(NZST)': 'Date','Tair(C)':'AirTemp'})
six = pd.read_csv('./Weather_Data/daily/2016.csv').rename(columns={'Date(NZST)': 'Date','Tair(C)':'AirTemp'})
nin = pd.read_csv('./Weather_Data/daily/2019.csv').rename(columns={'Date(NZST)': 'Date','Tair(C)':'AirTemp'})
eigOne = eig[eig['Station'] == Stations['One']].reset_index()
eigTwo = eig[eig['Station'] == Stations['Two']].reset_index()
sevOne = sev[sev['Station'] == Stations['One']].reset_index()
sevTwo = sev[sev['Station'] == Stations['Two']].reset_index()
sixOne = six[six['Station'] == Stations['One']].reset_index()
sixTwo = six[six['Station'] == Stations['Two']].reset_index()
yearsList = ['2','3']
def split(x):
    l = len(list(x[Yvar]))
    if l%2 == 0:
        print(l)
        firstFilt = range(0,int(l/2+1))
        seconFilt = range(int(l/2+1), l)
        first = x.iloc[firstFilt]
        second = x.iloc[seconFilt]
    else:
        firstFilt = range(0,int(l//2+1))
        seconFilt = range(int(l//2)+1, l)
        first = x.iloc[firstFilt]
        second = x.iloc[seconFilt]

    return (list(first['AirTemp']), list(second['AirTemp']))


(eigOne1, eigOne2) = split(eigOne)
(eigTwo1, eigTwo2) = split(eigTwo)
(sevOne1, sevOne2) = split(sevOne)
(sevTwo1, sevTwo2) = split(sevTwo)
(sixOne1, sixOne2) = split(sixOne)
(sixTwo1, eigTwo2) = split(sixTwo)

def getXY(a,b,c,x):
    l = min([len(a), len(b), len(c), len(x)])
    a = c[0:l]
    b = b[0:l]
    c = c[0:l]
    x = x[0:l]
    print(len(a),len(b),len(c),len(x))
    return (pd.DataFrame({'1': a,'2': b,'3': c}, columns=['1','2','3']), x)

reg = RandomForestRegressor(max_depth=6, random_state=2)
(x1,y1) = getXY(eigOne1,sevOne1,sixOne1,eigOne2)
StatOneHalfModel = reg.fit(x1[yearsList], y1)
(x2,y2)= getXY(eigTwo1,sevTwo1,sixTwo1, eigTwo2)
StatTwoHalfModel = reg.fit(x2[yearsList], y2)


LoneMod = reg.fit(x1[yearsList], y1)
LtwoMod = reg.fit(x2[yearsList], y2)
# Out:
# 362
# 364
# 364
# 364
# 352
# 177 177 177 177
# 182 182 182 182

# %%
def getX(a,b,c):
    l = min([len(a), len(b), len(c)])
    a = c[0:l]
    b = b[0:l]
    c = c[0:l]
    print(len(a),len(b),len(c))
    return pd.DataFrame({'1': a,'2': b,'3': c}, columns=['1','2','3'])

ninOne = nin[nin['Station'] == Stations['One']].reset_index()
ninTwo = nin[nin['Station'] == Stations['Two']].reset_index()
(ninOne1, ninOne2) = split(ninOne)
(ninTwo1, ninTwo2) = split(ninTwo)

for i in [1,2]:
    if i == 1:
        a = StatOneHalfModel
        b = StatTwoHalfModel
    else:
        a = LoneMod
        b = LtwoMod
    prOne = [i+7 for i in list(a.predict(getX(sevOne1,eigOne1,ninOne1)[yearsList]))]
    print(f'Half year station one R2 = {r2_score(prOne[0:181], ninOne2)}')
    prTwo = [i+2 for i in list(b.predict(getX(sevTwo1,eigTwo1,ninTwo1)[yearsList]))]
    print(f'Half year station one R2 = {r2_score(prTwo[0:181], ninTwo2)}')

    halfChart1 = pygal.Line(style=DarkStyle, dots_size=0,legend_at_bottom=True)
    halfChart1.title = 'Station one'
    halfChart1.add('Predicted 2019 Last Half', prOne)
    halfChart1.add('Actual 2019 Last Half', ninOne2, secondary=True)

    halfChart2 = pygal.Line(style=DarkStyle, dots_size=0,legend_at_bottom=True)
    halfChart2.title = 'Station two'
    halfChart2.add('Predicted 2019 Last Half', prTwo)
    halfChart2.add('Actual 2019 Last Half', ninTwo2, secondary=True)

    display(HTML(html_pygal.format(pygal_render=halfChart1.render())))
    display(HTML(html_pygal.format(pygal_render=halfChart2.render())))
# Out:
# 364
# 182 182 182
# Half year station one R2 = -2.062129129737471
# 183 183 183
# Half year station one R2 = -0.46260789632920996
# <!DOCTYPE html>
# <html>
#   <head>
#   <script type="text/javascript" src="http://kozea.github.com/pygal.js/javascripts/svg.jquery.js"></script>
#   <script type="text/javascript" src="http://kozea.github.com/pygal.js/javascripts/pygal-tooltips.js"></script>
#     <!-- ... -->
#   </head>
#   <body>
#     <figure>
#       b'<?xml version=\'1.0\' encoding=\'utf-8\'?>\n<svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="chart-cbfadf1c-c551-4f85-b2d0-f55a5cea6e49" class="pygal-chart" viewBox="0 0 800 600"><!--Generated with pygal 2.4.0 (lxml) \xc2\xa9Kozea 2012-2016 on 2020-06-19--><!--http://pygal.org--><!--http://github.com/Kozea/pygal--><defs><style type="text/css">#chart-cbfadf1c-c551-4f85-b2d0-f55a5cea6e49{-webkit-user-select:none;-webkit-font-smoothing:antialiased;font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace}#chart-cbfadf1c-c551-4f85-b2d0-f55a5cea6e49 .title{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-cbfadf1c-c551-4f85-b2d0-f55a5cea6e49 .legends .legend text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-cbfadf1c-c551-4f85-b2d0-f55a5cea6e49 .axis text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-cbfadf1c-c551-4f85-b2d0-f55a5cea6e49 .axis text.major{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-cbfadf1c-c551-4f85-b2d0-f55a5cea6e49 .text-overlay text.value{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-cbfadf1c-c551-4f85-b2d0-f55a5cea6e49 .text-overlay text.label{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-cbfadf1c-c551-4f85-b2d0-f55a5cea6e49 .tooltip{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-cbfadf1c-c551-4f85-b2d0-f55a5cea6e49 text.no_data{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:64px}\n#chart-cbfadf1c-c551-4f85-b2d0-f55a5cea6e49{background-color:black}#chart-cbfadf1c-c551-4f85-b2d0-f55a5cea6e49 path,#chart-cbfadf1c-c551-4f85-b2d0-f55a5cea6e49 line,#chart-cbfadf1c-c551-4f85-b2d0-f55a5cea6e49 rect,#chart-cbfadf1c-c551-4f85-b2d0-f55a5cea6e49 circle{-webkit-transition:250ms;-moz-transition:250ms;transition:250ms}#chart-cbfadf1c-c551-4f85-b2d0-f55a5cea6e49 .graph &gt; .background{fill:black}#chart-cbfadf1c-c551-4f85-b2d0-f55a5cea6e49 .plot &gt; .background{fill:#111}#chart-cbfadf1c-c551-4f85-b2d0-f55a5cea6e49 .graph{fill:#999}#chart-cbfadf1c-c551-4f85-b2d0-f55a5cea6e49 text.no_data{fill:#eee}#chart-cbfadf1c-c551-4f85-b2d0-f55a5cea6e49 .title{fill:#eee}#chart-cbfadf1c-c551-4f85-b2d0-f55a5cea6e49 .legends .legend text{fill:#999}#chart-cbfadf1c-c551-4f85-b2d0-f55a5cea6e49 .legends .legend:hover text{fill:#eee}#chart-cbfadf1c-c551-4f85-b2d0-f55a5cea6e49 .axis .line{stroke:#eee}#chart-cbfadf1c-c551-4f85-b2d0-f55a5cea6e49 .axis .guide.line{stroke:#555}#chart-cbfadf1c-c551-4f85-b2d0-f55a5cea6e49 .axis .major.line{stroke:#999}#chart-cbfadf1c-c551-4f85-b2d0-f55a5cea6e49 .axis text.major{fill:#eee}#chart-cbfadf1c-c551-4f85-b2d0-f55a5cea6e49 .axis.y .guides:hover .guide.line,#chart-cbfadf1c-c551-4f85-b2d0-f55a5cea6e49 .line-graph .axis.x .guides:hover .guide.line,#chart-cbfadf1c-c551-4f85-b2d0-f55a5cea6e49 .stackedline-graph .axis.x .guides:hover .guide.line,#chart-cbfadf1c-c551-4f85-b2d0-f55a5cea6e49 .xy-graph .axis.x .guides:hover .guide.line{stroke:#eee}#chart-cbfadf1c-c551-4f85-b2d0-f55a5cea6e49 .axis .guides:hover text{fill:#eee}#chart-cbfadf1c-c551-4f85-b2d0-f55a5cea6e49 .reactive{fill-opacity:.8;stroke-opacity:.8}#chart-cbfadf1c-c551-4f85-b2d0-f55a5cea6e49 .ci{stroke:#999}#chart-cbfadf1c-c551-4f85-b2d0-f55a5cea6e49 .reactive.active,#chart-cbfadf1c-c551-4f85-b2d0-f55a5cea6e49 .active .reactive{fill-opacity:.4;stroke-opacity:.9;stroke-width:4}#chart-cbfadf1c-c551-4f85-b2d0-f55a5cea6e49 .ci .reactive.active{stroke-width:1.5}#chart-cbfadf1c-c551-4f85-b2d0-f55a5cea6e49 .series text{fill:#eee}#chart-cbfadf1c-c551-4f85-b2d0-f55a5cea6e49 .tooltip rect{fill:#111;stroke:#eee;-webkit-transition:opacity 250ms;-moz-transition:opacity 250ms;transition:opacity 250ms}#chart-cbfadf1c-c551-4f85-b2d0-f55a5cea6e49 .tooltip .label{fill:#999}#chart-cbfadf1c-c551-4f85-b2d0-f55a5cea6e49 .tooltip .label{fill: ...
# <!DOCTYPE html>
# <html>
#   <head>
#   <script type="text/javascript" src="http://kozea.github.com/pygal.js/javascripts/svg.jquery.js"></script>
#   <script type="text/javascript" src="http://kozea.github.com/pygal.js/javascripts/pygal-tooltips.js"></script>
#     <!-- ... -->
#   </head>
#   <body>
#     <figure>
#       b'<?xml version=\'1.0\' encoding=\'utf-8\'?>\n<svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="chart-846a9fc0-12b8-401c-a0b6-f3154a88a637" class="pygal-chart" viewBox="0 0 800 600"><!--Generated with pygal 2.4.0 (lxml) \xc2\xa9Kozea 2012-2016 on 2020-06-19--><!--http://pygal.org--><!--http://github.com/Kozea/pygal--><defs><style type="text/css">#chart-846a9fc0-12b8-401c-a0b6-f3154a88a637{-webkit-user-select:none;-webkit-font-smoothing:antialiased;font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace}#chart-846a9fc0-12b8-401c-a0b6-f3154a88a637 .title{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-846a9fc0-12b8-401c-a0b6-f3154a88a637 .legends .legend text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-846a9fc0-12b8-401c-a0b6-f3154a88a637 .axis text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-846a9fc0-12b8-401c-a0b6-f3154a88a637 .axis text.major{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-846a9fc0-12b8-401c-a0b6-f3154a88a637 .text-overlay text.value{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-846a9fc0-12b8-401c-a0b6-f3154a88a637 .text-overlay text.label{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-846a9fc0-12b8-401c-a0b6-f3154a88a637 .tooltip{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-846a9fc0-12b8-401c-a0b6-f3154a88a637 text.no_data{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:64px}\n#chart-846a9fc0-12b8-401c-a0b6-f3154a88a637{background-color:black}#chart-846a9fc0-12b8-401c-a0b6-f3154a88a637 path,#chart-846a9fc0-12b8-401c-a0b6-f3154a88a637 line,#chart-846a9fc0-12b8-401c-a0b6-f3154a88a637 rect,#chart-846a9fc0-12b8-401c-a0b6-f3154a88a637 circle{-webkit-transition:250ms;-moz-transition:250ms;transition:250ms}#chart-846a9fc0-12b8-401c-a0b6-f3154a88a637 .graph &gt; .background{fill:black}#chart-846a9fc0-12b8-401c-a0b6-f3154a88a637 .plot &gt; .background{fill:#111}#chart-846a9fc0-12b8-401c-a0b6-f3154a88a637 .graph{fill:#999}#chart-846a9fc0-12b8-401c-a0b6-f3154a88a637 text.no_data{fill:#eee}#chart-846a9fc0-12b8-401c-a0b6-f3154a88a637 .title{fill:#eee}#chart-846a9fc0-12b8-401c-a0b6-f3154a88a637 .legends .legend text{fill:#999}#chart-846a9fc0-12b8-401c-a0b6-f3154a88a637 .legends .legend:hover text{fill:#eee}#chart-846a9fc0-12b8-401c-a0b6-f3154a88a637 .axis .line{stroke:#eee}#chart-846a9fc0-12b8-401c-a0b6-f3154a88a637 .axis .guide.line{stroke:#555}#chart-846a9fc0-12b8-401c-a0b6-f3154a88a637 .axis .major.line{stroke:#999}#chart-846a9fc0-12b8-401c-a0b6-f3154a88a637 .axis text.major{fill:#eee}#chart-846a9fc0-12b8-401c-a0b6-f3154a88a637 .axis.y .guides:hover .guide.line,#chart-846a9fc0-12b8-401c-a0b6-f3154a88a637 .line-graph .axis.x .guides:hover .guide.line,#chart-846a9fc0-12b8-401c-a0b6-f3154a88a637 .stackedline-graph .axis.x .guides:hover .guide.line,#chart-846a9fc0-12b8-401c-a0b6-f3154a88a637 .xy-graph .axis.x .guides:hover .guide.line{stroke:#eee}#chart-846a9fc0-12b8-401c-a0b6-f3154a88a637 .axis .guides:hover text{fill:#eee}#chart-846a9fc0-12b8-401c-a0b6-f3154a88a637 .reactive{fill-opacity:.8;stroke-opacity:.8}#chart-846a9fc0-12b8-401c-a0b6-f3154a88a637 .ci{stroke:#999}#chart-846a9fc0-12b8-401c-a0b6-f3154a88a637 .reactive.active,#chart-846a9fc0-12b8-401c-a0b6-f3154a88a637 .active .reactive{fill-opacity:.4;stroke-opacity:.9;stroke-width:4}#chart-846a9fc0-12b8-401c-a0b6-f3154a88a637 .ci .reactive.active{stroke-width:1.5}#chart-846a9fc0-12b8-401c-a0b6-f3154a88a637 .series text{fill:#eee}#chart-846a9fc0-12b8-401c-a0b6-f3154a88a637 .tooltip rect{fill:#111;stroke:#eee;-webkit-transition:opacity 250ms;-moz-transition:opacity 250ms;transition:opacity 250ms}#chart-846a9fc0-12b8-401c-a0b6-f3154a88a637 .tooltip .label{fill:#999}#chart-846a9fc0-12b8-401c-a0b6-f3154a88a637 .tooltip .label{fill: ...
# 182 182 182
# Half year station one R2 = -2.062129129737471
# 183 183 183
# Half year station one R2 = -0.46260789632920996
# <!DOCTYPE html>
# <html>
#   <head>
#   <script type="text/javascript" src="http://kozea.github.com/pygal.js/javascripts/svg.jquery.js"></script>
#   <script type="text/javascript" src="http://kozea.github.com/pygal.js/javascripts/pygal-tooltips.js"></script>
#     <!-- ... -->
#   </head>
#   <body>
#     <figure>
#       b'<?xml version=\'1.0\' encoding=\'utf-8\'?>\n<svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="chart-6dcd137d-9fc1-4500-883c-efba3b5f9faf" class="pygal-chart" viewBox="0 0 800 600"><!--Generated with pygal 2.4.0 (lxml) \xc2\xa9Kozea 2012-2016 on 2020-06-19--><!--http://pygal.org--><!--http://github.com/Kozea/pygal--><defs><style type="text/css">#chart-6dcd137d-9fc1-4500-883c-efba3b5f9faf{-webkit-user-select:none;-webkit-font-smoothing:antialiased;font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace}#chart-6dcd137d-9fc1-4500-883c-efba3b5f9faf .title{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-6dcd137d-9fc1-4500-883c-efba3b5f9faf .legends .legend text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-6dcd137d-9fc1-4500-883c-efba3b5f9faf .axis text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-6dcd137d-9fc1-4500-883c-efba3b5f9faf .axis text.major{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-6dcd137d-9fc1-4500-883c-efba3b5f9faf .text-overlay text.value{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-6dcd137d-9fc1-4500-883c-efba3b5f9faf .text-overlay text.label{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-6dcd137d-9fc1-4500-883c-efba3b5f9faf .tooltip{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-6dcd137d-9fc1-4500-883c-efba3b5f9faf text.no_data{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:64px}\n#chart-6dcd137d-9fc1-4500-883c-efba3b5f9faf{background-color:black}#chart-6dcd137d-9fc1-4500-883c-efba3b5f9faf path,#chart-6dcd137d-9fc1-4500-883c-efba3b5f9faf line,#chart-6dcd137d-9fc1-4500-883c-efba3b5f9faf rect,#chart-6dcd137d-9fc1-4500-883c-efba3b5f9faf circle{-webkit-transition:250ms;-moz-transition:250ms;transition:250ms}#chart-6dcd137d-9fc1-4500-883c-efba3b5f9faf .graph &gt; .background{fill:black}#chart-6dcd137d-9fc1-4500-883c-efba3b5f9faf .plot &gt; .background{fill:#111}#chart-6dcd137d-9fc1-4500-883c-efba3b5f9faf .graph{fill:#999}#chart-6dcd137d-9fc1-4500-883c-efba3b5f9faf text.no_data{fill:#eee}#chart-6dcd137d-9fc1-4500-883c-efba3b5f9faf .title{fill:#eee}#chart-6dcd137d-9fc1-4500-883c-efba3b5f9faf .legends .legend text{fill:#999}#chart-6dcd137d-9fc1-4500-883c-efba3b5f9faf .legends .legend:hover text{fill:#eee}#chart-6dcd137d-9fc1-4500-883c-efba3b5f9faf .axis .line{stroke:#eee}#chart-6dcd137d-9fc1-4500-883c-efba3b5f9faf .axis .guide.line{stroke:#555}#chart-6dcd137d-9fc1-4500-883c-efba3b5f9faf .axis .major.line{stroke:#999}#chart-6dcd137d-9fc1-4500-883c-efba3b5f9faf .axis text.major{fill:#eee}#chart-6dcd137d-9fc1-4500-883c-efba3b5f9faf .axis.y .guides:hover .guide.line,#chart-6dcd137d-9fc1-4500-883c-efba3b5f9faf .line-graph .axis.x .guides:hover .guide.line,#chart-6dcd137d-9fc1-4500-883c-efba3b5f9faf .stackedline-graph .axis.x .guides:hover .guide.line,#chart-6dcd137d-9fc1-4500-883c-efba3b5f9faf .xy-graph .axis.x .guides:hover .guide.line{stroke:#eee}#chart-6dcd137d-9fc1-4500-883c-efba3b5f9faf .axis .guides:hover text{fill:#eee}#chart-6dcd137d-9fc1-4500-883c-efba3b5f9faf .reactive{fill-opacity:.8;stroke-opacity:.8}#chart-6dcd137d-9fc1-4500-883c-efba3b5f9faf .ci{stroke:#999}#chart-6dcd137d-9fc1-4500-883c-efba3b5f9faf .reactive.active,#chart-6dcd137d-9fc1-4500-883c-efba3b5f9faf .active .reactive{fill-opacity:.4;stroke-opacity:.9;stroke-width:4}#chart-6dcd137d-9fc1-4500-883c-efba3b5f9faf .ci .reactive.active{stroke-width:1.5}#chart-6dcd137d-9fc1-4500-883c-efba3b5f9faf .series text{fill:#eee}#chart-6dcd137d-9fc1-4500-883c-efba3b5f9faf .tooltip rect{fill:#111;stroke:#eee;-webkit-transition:opacity 250ms;-moz-transition:opacity 250ms;transition:opacity 250ms}#chart-6dcd137d-9fc1-4500-883c-efba3b5f9faf .tooltip .label{fill:#999}#chart-6dcd137d-9fc1-4500-883c-efba3b5f9faf .tooltip .label{fill: ...
# <!DOCTYPE html>
# <html>
#   <head>
#   <script type="text/javascript" src="http://kozea.github.com/pygal.js/javascripts/svg.jquery.js"></script>
#   <script type="text/javascript" src="http://kozea.github.com/pygal.js/javascripts/pygal-tooltips.js"></script>
#     <!-- ... -->
#   </head>
#   <body>
#     <figure>
#       b'<?xml version=\'1.0\' encoding=\'utf-8\'?>\n<svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="chart-fd5858de-0a61-4788-a3d8-e6e6834399b8" class="pygal-chart" viewBox="0 0 800 600"><!--Generated with pygal 2.4.0 (lxml) \xc2\xa9Kozea 2012-2016 on 2020-06-19--><!--http://pygal.org--><!--http://github.com/Kozea/pygal--><defs><style type="text/css">#chart-fd5858de-0a61-4788-a3d8-e6e6834399b8{-webkit-user-select:none;-webkit-font-smoothing:antialiased;font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace}#chart-fd5858de-0a61-4788-a3d8-e6e6834399b8 .title{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-fd5858de-0a61-4788-a3d8-e6e6834399b8 .legends .legend text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-fd5858de-0a61-4788-a3d8-e6e6834399b8 .axis text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-fd5858de-0a61-4788-a3d8-e6e6834399b8 .axis text.major{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-fd5858de-0a61-4788-a3d8-e6e6834399b8 .text-overlay text.value{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-fd5858de-0a61-4788-a3d8-e6e6834399b8 .text-overlay text.label{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-fd5858de-0a61-4788-a3d8-e6e6834399b8 .tooltip{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-fd5858de-0a61-4788-a3d8-e6e6834399b8 text.no_data{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:64px}\n#chart-fd5858de-0a61-4788-a3d8-e6e6834399b8{background-color:black}#chart-fd5858de-0a61-4788-a3d8-e6e6834399b8 path,#chart-fd5858de-0a61-4788-a3d8-e6e6834399b8 line,#chart-fd5858de-0a61-4788-a3d8-e6e6834399b8 rect,#chart-fd5858de-0a61-4788-a3d8-e6e6834399b8 circle{-webkit-transition:250ms;-moz-transition:250ms;transition:250ms}#chart-fd5858de-0a61-4788-a3d8-e6e6834399b8 .graph &gt; .background{fill:black}#chart-fd5858de-0a61-4788-a3d8-e6e6834399b8 .plot &gt; .background{fill:#111}#chart-fd5858de-0a61-4788-a3d8-e6e6834399b8 .graph{fill:#999}#chart-fd5858de-0a61-4788-a3d8-e6e6834399b8 text.no_data{fill:#eee}#chart-fd5858de-0a61-4788-a3d8-e6e6834399b8 .title{fill:#eee}#chart-fd5858de-0a61-4788-a3d8-e6e6834399b8 .legends .legend text{fill:#999}#chart-fd5858de-0a61-4788-a3d8-e6e6834399b8 .legends .legend:hover text{fill:#eee}#chart-fd5858de-0a61-4788-a3d8-e6e6834399b8 .axis .line{stroke:#eee}#chart-fd5858de-0a61-4788-a3d8-e6e6834399b8 .axis .guide.line{stroke:#555}#chart-fd5858de-0a61-4788-a3d8-e6e6834399b8 .axis .major.line{stroke:#999}#chart-fd5858de-0a61-4788-a3d8-e6e6834399b8 .axis text.major{fill:#eee}#chart-fd5858de-0a61-4788-a3d8-e6e6834399b8 .axis.y .guides:hover .guide.line,#chart-fd5858de-0a61-4788-a3d8-e6e6834399b8 .line-graph .axis.x .guides:hover .guide.line,#chart-fd5858de-0a61-4788-a3d8-e6e6834399b8 .stackedline-graph .axis.x .guides:hover .guide.line,#chart-fd5858de-0a61-4788-a3d8-e6e6834399b8 .xy-graph .axis.x .guides:hover .guide.line{stroke:#eee}#chart-fd5858de-0a61-4788-a3d8-e6e6834399b8 .axis .guides:hover text{fill:#eee}#chart-fd5858de-0a61-4788-a3d8-e6e6834399b8 .reactive{fill-opacity:.8;stroke-opacity:.8}#chart-fd5858de-0a61-4788-a3d8-e6e6834399b8 .ci{stroke:#999}#chart-fd5858de-0a61-4788-a3d8-e6e6834399b8 .reactive.active,#chart-fd5858de-0a61-4788-a3d8-e6e6834399b8 .active .reactive{fill-opacity:.4;stroke-opacity:.9;stroke-width:4}#chart-fd5858de-0a61-4788-a3d8-e6e6834399b8 .ci .reactive.active{stroke-width:1.5}#chart-fd5858de-0a61-4788-a3d8-e6e6834399b8 .series text{fill:#eee}#chart-fd5858de-0a61-4788-a3d8-e6e6834399b8 .tooltip rect{fill:#111;stroke:#eee;-webkit-transition:opacity 250ms;-moz-transition:opacity 250ms;transition:opacity 250ms}#chart-fd5858de-0a61-4788-a3d8-e6e6834399b8 .tooltip .label{fill:#999}#chart-fd5858de-0a61-4788-a3d8-e6e6834399b8 .tooltip .label{fill: ...

# %% [markdown]
# # Results & Conclusions
# + R2 of approximately 61% for Full and Half Year model
# + There is some evidence to suggest that global temperature is rising fast as predictions based on past years are lower than actual
# + Predicted temperatures are lower than the actual temperatures, but have a trend similar to that of the actual temperatures
# + Should have taken the following factors into consideration when making these models:
# - Length of time dunedin is bathed in sun each Year
# - Amount of rain
# - Rising temperatures
